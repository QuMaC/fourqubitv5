# %%
from qm import QuantumMachinesManager
import time
import matplotlib.pyplot as plt
from configuration import *
import numpy as np
import scipy.optimize as opti
from auto_mixer_tools_visa import KeysightFieldFox
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 4>()
#       2 import time
#       3 import matplotlib.pyplot as plt
# ----> 4 from configuration import *
#       5 import numpy as np
#       6 import scipy.optimize as opti
#
# File ~\Instrumentation-Python\Keysight-SC\configuration.py:2, in <module>
#       1 from scipy.signal import gaussian
# ----> 2 from helper_functions import *
#       4 qb_LO = 4.829e9
#       5 qb_IF = 100.145e6
#
# ModuleNotFoundError: No module named 'helper_functions'
